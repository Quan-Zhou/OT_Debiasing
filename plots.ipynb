# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
report=pd.read_csv('C:/Users/zhouq/Documents/optimal_transport/report_postprocess_quicksex.csv')
performance=list(report.columns)[:-1]
methods=['origin','baseline','partial repair2','partial repair3','partial repair4'] #,'partial repair4','barycentre'
#list(set(report['method']))
colors=['#5f0f40','#9a031e','#FF8811','#F4D06F','#9DD9D2'] #' dark purple
pivot=pd.pivot_table(report,index=['method'],values=performance,aggfunc=[np.mean,np.std])
pivot
# Out:
#                      mean                                       std            \
#                        DI  f1 macro  f1 micro f1 weighted        DI  f1 macro
# method
# baseline         0.413367  0.683064  0.817613    0.790221  0.009198  0.005259
# origin           0.413367  0.683064  0.817613    0.790221  0.009198  0.005259
# partial repair2  0.441104  0.629868  0.806797    0.762657  0.024754  0.008528
# partial repair3  0.463168  0.618066  0.804868    0.756666  0.029004  0.008705
# partial repair4  0.460712  0.618790  0.805093    0.757074  0.036346  0.009445
#
#
#                  f1 micro f1 weighted
# method
# baseline         0.001761    0.003220
# origin           0.001761    0.003220
# partial repair2  0.002167    0.004976
# partial repair3  0.002055    0.005068
# partial repair4  0.002291    0.005431

# %%
ind=np.arange(len(performance))
width = 0.15

fig, ax1 = plt.subplots(figsize=(12,6))

i=0
for m in methods:
    sub=[pivot[('mean',p)][m] for p in performance]
    err=[pivot[('std',p)][m] for p in performance]
    ax1.bar(ind+width*i,sub,width,yerr=err,color=colors[i],label=m)
    i+=1
    
ax1.legend(['Origin','Baseline',r'$10^{-2}$-repair',r'$10^{-3}$-repair','Barycentre'],fontsize=14,
            framealpha=0.2,bbox_to_anchor=(1.0,1.1),ncol=5,frameon=False)
ax1.set_xlabel('Indices', fontsize=20)
ax1.set_ylabel('Values', fontsize=20)

ax1.set_xticks(ind+width*2)
ax1.set_xticklabels(['DisparateImpact']+[i for i in performance[1:]], fontsize=16)
ax1.tick_params(axis='y', which='major', labelsize=14)

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#plt.savefig("C:/Users/zhouq/Documents/optimal_transport/adult_higher_race.pdf",bbox_inches='tight')

# %%
report=pd.read_csv('C:/Users/zhouq/Documents/optimal_transport/report_higher_rw.csv')
report=report[report['test set']=='origin']
report=report.drop(['test set'],axis=1)
performance=list(report.columns)[:-1]
#methods=['origin','baseline','partial repair']
methods=['origin','baseline','partial_repair2','partial_repair3','partial_repair4']
#list(set(report['method']))
colors=['#5f0f40','#9a031e','#FF8811','#F4D06F','#9DD9D2']
pivot=pd.pivot_table(report,index=['method'],values=performance,aggfunc=[np.mean,np.std])
print(pivot)
ind=np.arange(len(performance))
width = 0.15

fig, ax1 = plt.subplots(figsize=(12,6))

i=0
for m in methods:
    sub=[pivot[('mean',p)][m] for p in performance]
    err=[pivot[('std',p)][m] for p in performance]
    ax1.bar(ind+width*i,sub,width,yerr=err,color=colors[i],label=m)
    i+=1
    
ax1.legend(['Origin','Baseline',r'$10^{-2}$-repair',r'$10^{-3}$-repair',r'$5\times 10^{-4}$-repair'],fontsize=14,
            framealpha=0.2,bbox_to_anchor=(1.03,1.1),ncol=5,frameon=False)
ax1.set_xlabel('Indices', fontsize=20)
ax1.set_ylabel('Values', fontsize=20)

ax1.set_xticks(ind+width*2)
ax1.set_xticklabels(['DisparateImpact']+[i for i in performance[1:]], fontsize=16)
ax1.tick_params(axis='y', which='major', labelsize=14)

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#plt.savefig("C:/Users/zhouq/Documents/optimal_transport/adult_higher.pdf",bbox_inches='tight')
# Out:
#                      mean                                       std            \
#                        DI  f1 macro  f1 micro f1 weighted        DI  f1 macro
# method
# baseline         0.453286  0.691998  0.818895    0.794611  0.051707  0.005586
# origin           0.456424  0.664646  0.812874    0.780361  0.060914  0.010087
# partial_repair2  0.560695  0.628519  0.806990    0.762164  0.070907  0.005815
# partial_repair3  0.567392  0.629033  0.806523    0.762223  0.072634  0.005228
# partial_repair4  0.567338  0.629119  0.806502    0.762251  0.072208  0.005390
#
#
#                  f1 micro f1 weighted
# method
# baseline         0.002928    0.003878
# origin           0.003139    0.005833
# partial_repair2  0.002856    0.004377
# partial_repair3  0.002803    0.003991
# partial_repair4  0.002897    0.004208

# %% [markdown]
# **X: education-num**
#
#  **Y: High income**
#
#  **S: Race or Gender**

# %%
report=pd.read_csv('C:/Users/zhouq/Documents/optimal_transport/report_race_onlyedu.csv')
report=report[report['test set']=='origin']
report=report.drop(['test set'],axis=1)
performance=list(report.columns)[:-1]
#methods=['origin','baseline','partial repair']
methods=['origin','baseline','partial repair']
#list(set(report['method']))
colors=['#5f0f40','#9a031e','#FF8811','#F4D06F','#9DD9D2']
pivot=pd.pivot_table(report,index=['method'],values=performance,aggfunc=[np.mean,np.std])
print(pivot)
ind=np.arange(len(performance))
width = 0.15

fig, ax1 = plt.subplots(figsize=(8,6))

i=0
for m in methods:
    sub=[pivot[('mean',p)][m] for p in performance]
    err=[pivot[('std',p)][m] for p in performance]
    ax1.bar(ind+width*i,sub,width,yerr=err,color=colors[i],label=m)
    i+=1
    
ax1.legend(['Origin','Baseline',r'$10^{-2}$-repair',r'$10^{-3}$-repair',r'$5\times 10^{-4}$-repair'],fontsize=14,
            framealpha=0.2,bbox_to_anchor=(1.03,1.1),ncol=5,frameon=False)
ax1.set_xlabel('Indices', fontsize=20)
ax1.set_ylabel('Values', fontsize=20)

ax1.set_xticks(ind+width*2)
ax1.set_xticklabels(['DisparateImpact']+[i for i in performance[1:]], fontsize=16)
ax1.tick_params(axis='y', which='major', labelsize=14)

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#plt.savefig("C:/Users/zhouq/Documents/optimal_transport/adult_higher.pdf",bbox_inches='tight')
# Out:
#                     mean                                       std            \
#                       DI  f1 macro  f1 micro f1 weighted        DI  f1 macro
# method
# baseline        0.363570  0.551295  0.776463    0.716838  0.132824  0.043005
# origin          0.486721  0.613044  0.771387    0.741227  0.072805  0.032404
# partial repair  0.248158  0.503122  0.772124    0.693649  0.064978  0.019293
#
#
#                 f1 micro f1 weighted
# method
# baseline        0.003836    0.020448
# origin          0.014331    0.007470
# partial repair  0.003573    0.009984

# %%
report=pd.read_csv('C:/Users/zhouq/Documents/optimal_transport/report_gender_onlyedu.csv')
report=report[report['test set']=='origin']
report=report.drop(['test set'],axis=1)
performance=list(report.columns)[:-1]
#methods=['origin','baseline','partial repair']
methods=['origin','baseline','partial repair']
#list(set(report['method']))
colors=['#5f0f40','#9a031e','#FF8811','#F4D06F','#9DD9D2']
pivot=pd.pivot_table(report,index=['method'],values=performance,aggfunc=[np.mean,np.std])
print(pivot)
ind=np.arange(len(performance))
width = 0.15

fig, ax1 = plt.subplots(figsize=(8,6))

i=0
for m in methods:
    sub=[pivot[('mean',p)][m] for p in performance]
    err=[pivot[('std',p)][m] for p in performance]
    ax1.bar(ind+width*i,sub,width,yerr=err,color=colors[i],label=m)
    i+=1
    
ax1.legend(['Origin','Baseline',r'$10^{-2}$-repair',r'$10^{-3}$-repair',r'$5\times 10^{-4}$-repair'],fontsize=14,
            framealpha=0.2,bbox_to_anchor=(1.03,1.1),ncol=5,frameon=False)
ax1.set_xlabel('Indices', fontsize=20)
ax1.set_ylabel('Values', fontsize=20)

ax1.set_xticks(ind+width*2)
ax1.set_xticklabels(['DisparateImpact']+[i for i in performance[1:]], fontsize=16)
ax1.tick_params(axis='y', which='major', labelsize=14)

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#plt.savefig("C:/Users/zhouq/Documents/optimal_transport/adult_higher.pdf",bbox_inches='tight')
# Out:
#                mean                                 std                     \
#                  DI  f1 macro  f1 micro f1 weighted  DI f1 macro  f1 micro
# method
# baseline          1  0.432084  0.760828    0.657488   0  0.00086  0.002662
# origin            1  0.432084  0.760828    0.657488   0  0.00086  0.002662
# partial repair    1  0.432084  0.760828    0.657488   0  0.00086  0.002662
#
#
#                f1 weighted
# method
# baseline          0.003604
# origin            0.003604
# partial repair    0.003604

# %% [markdown]
# ***X: age, education-num, capitalgain, capitalloss, hoursperweek***
#
#  **Y: High income**
#
#  **S: Race or Gender**

# %%
report=pd.read_csv('C:/Users/zhouq/Documents/optimal_transport/report_higher_rw.csv')
report=report[report['test set']=='origin']
report=report.drop(['test set'],axis=1)
performance=list(report.columns)[:-1]
#methods=['origin','baseline','partial repair']
methods=['origin','baseline','partial_repair2','partial_repair3','partial_repair4']
#list(set(report['method']))
colors=['#5f0f40','#9a031e','#FF8811','#F4D06F','#9DD9D2']
pivot=pd.pivot_table(report,index=['method'],values=performance,aggfunc=[np.mean,np.std])
print(pivot)
ind=np.arange(len(performance))
width = 0.15

fig, ax1 = plt.subplots(figsize=(12,6))

i=0
for m in methods:
    sub=[pivot[('mean',p)][m] for p in performance]
    err=[pivot[('std',p)][m] for p in performance]
    ax1.bar(ind+width*i,sub,width,yerr=err,color=colors[i],label=m)
    i+=1
    
ax1.legend(['Origin','Baseline',r'$10^{-2}$-repair',r'$10^{-3}$-repair',r'$5\times 10^{-4}$-repair'],fontsize=14,
            framealpha=0.2,bbox_to_anchor=(1.03,1.1),ncol=5,frameon=False)
ax1.set_xlabel('Indices', fontsize=20)
ax1.set_ylabel('Values', fontsize=20)

ax1.set_xticks(ind+width*2)
ax1.set_xticklabels(['DisparateImpact']+[i for i in performance[1:]], fontsize=16)
ax1.tick_params(axis='y', which='major', labelsize=14)

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#plt.savefig("C:/Users/zhouq/Documents/optimal_transport/adult_higher.pdf",bbox_inches='tight')
# Out:
#                      mean                                       std            \
#                        DI  f1 macro  f1 micro f1 weighted        DI  f1 macro
# method
# baseline         0.453286  0.691998  0.818895    0.794611  0.051707  0.005586
# origin           0.456424  0.664646  0.812874    0.780361  0.060914  0.010087
# partial_repair2  0.560695  0.628519  0.806990    0.762164  0.070907  0.005815
# partial_repair3  0.567392  0.629033  0.806523    0.762223  0.072634  0.005228
# partial_repair4  0.567338  0.629119  0.806502    0.762251  0.072208  0.005390
#
#
#                  f1 micro f1 weighted
# method
# baseline         0.002928    0.003878
# origin           0.003139    0.005833
# partial_repair2  0.002856    0.004377
# partial_repair3  0.002803    0.003991
# partial_repair4  0.002897    0.004208

# %%
report=pd.read_csv('C:/Users/zhouq/Documents/optimal_transport/report_higher_gender_nonedu.csv')
# report=report[report['test set']=='origin']
# report=report.drop(['test set'],axis=1)
performance=list(report.columns)[:-1]
#methods=['origin','baseline','partial repair']
methods=['origin','baseline','partial_repair2','partial_repair3','partial_repair4']
#list(set(report['method']))
colors=['#5f0f40','#9a031e','#FF8811','#F4D06F','#9DD9D2']
pivot=pd.pivot_table(report,index=['method'],values=performance,aggfunc=[np.mean,np.std])
print(pivot)
ind=np.arange(len(performance))
width = 0.15

fig, ax1 = plt.subplots(figsize=(12,6))

i=0
for m in methods:
    sub=[pivot[('mean',p)][m] for p in performance]
    err=[pivot[('std',p)][m] for p in performance]
    ax1.bar(ind+width*i,sub,width,yerr=err,color=colors[i],label=m)
    i+=1
    
ax1.legend(['Origin','Baseline',r'$10^{-2}$-repair',r'$10^{-3}$-repair',r'$5\times 10^{-4}$-repair'],fontsize=14,
            framealpha=0.2,bbox_to_anchor=(1.03,1.1),ncol=5,frameon=False)
ax1.set_xlabel('Indices', fontsize=20)
ax1.set_ylabel('Values', fontsize=20)

ax1.set_xticks(ind+width*2)
ax1.set_xticklabels(['DisparateImpact']+[i for i in performance[1:]], fontsize=16)
ax1.tick_params(axis='y', which='major', labelsize=14)

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#plt.savefig("C:/Users/zhouq/Documents/optimal_transport/adult_higher.pdf",bbox_inches='tight')
# Out:
#                      mean                                       std            \
#                        DI  f1 macro  f1 micro f1 weighted        DI  f1 macro
# method
# baseline         0.456415  0.687842  0.819468    0.793519  0.033163  0.007786
# origin           0.423523  0.663728  0.813786    0.780830  0.021879  0.011590
# partial_repair2  0.480956  0.665687  0.816242    0.782641  0.038185  0.009536
# partial_repair3  0.484412  0.654607  0.813569    0.776763  0.033281  0.010399
# partial_repair4  0.474341  0.657282  0.813970    0.778087  0.038805  0.014103
#
#
#                  f1 micro f1 weighted
# method
# baseline         0.003204    0.004493
# origin           0.003442    0.006406
# partial_repair2  0.002933    0.005444
# partial_repair3  0.003312    0.005890
# partial_repair4  0.003439    0.007246

# %%
report=pd.read_csv('C:/Users/zhouq/Documents/optimal_transport/report_higher_gender.csv')
# report=report[report['test set']=='origin']
# report=report.drop(['test set'],axis=1)
performance=list(report.columns)[:-1]
#methods=['origin','baseline','partial repair']
methods=['origin','baseline','partial_repair2','partial_repair3','partial_repair4']
#list(set(report['method']))
colors=['#5f0f40','#9a031e','#FF8811','#F4D06F','#9DD9D2']
pivot=pd.pivot_table(report,index=['method'],values=performance,aggfunc=[np.mean,np.std])
print(pivot)
ind=np.arange(len(performance))
width = 0.15

fig, ax1 = plt.subplots(figsize=(12,6))

i=0
for m in methods:
    sub=[pivot[('mean',p)][m] for p in performance]
    err=[pivot[('std',p)][m] for p in performance]
    ax1.bar(ind+width*i,sub,width,yerr=err,color=colors[i],label=m)
    i+=1
    
ax1.legend(['Origin','Baseline',r'$10^{-2}$-repair',r'$10^{-3}$-repair',r'$5\times 10^{-4}$-repair'],fontsize=14,
            framealpha=0.2,bbox_to_anchor=(1.03,1.1),ncol=5,frameon=False)
ax1.set_xlabel('Indices', fontsize=20)
ax1.set_ylabel('Values', fontsize=20)

ax1.set_xticks(ind+width*2)
ax1.set_xticklabels(['DisparateImpact']+[i for i in performance[1:]], fontsize=16)
ax1.tick_params(axis='y', which='major', labelsize=14)

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

#plt.savefig("C:/Users/zhouq/Documents/optimal_transport/adult_higher.pdf",bbox_inches='tight')
# Out:
#                      mean                                       std            \
#                        DI  f1 macro  f1 micro f1 weighted        DI  f1 macro
# method
# baseline         0.461201  0.688754  0.819370    0.793947  0.036161  0.005791
# origin           0.424508  0.662462  0.813858    0.780393  0.028947  0.007765
# partial_repair2  0.457366  0.685678  0.819257    0.792581  0.037582  0.005774
# partial_repair3  0.450316  0.623319  0.808133    0.760993  0.042643  0.007185
# partial_repair4  0.457483  0.622584  0.807794    0.760532  0.042073  0.006456
#
#
#                  f1 micro f1 weighted
# method
# baseline         0.002811    0.003542
# origin           0.002735    0.004685
# partial_repair2  0.002706    0.003426
# partial_repair3  0.001977    0.003195
# partial_repair4  0.002197    0.003438

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt

from aif360.algorithms.preprocessing import DisparateImpactRemover,Reweighing,LFR
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import BinaryLabelDatasetMetric

from sklearn.ensemble import RandomForestClassifier
from aif360.datasets import CompasDataset, AdultDataset

from sklearn.metrics import f1_score
from functions import*

import os
path=os.path.dirname(os.getcwd())

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

"""
# if you need "OptimPreproc"
from aif360.algorithms.preprocessing.optim_preproc import OptimPreproc
from aif360.algorithms.preprocessing.optim_preproc_helpers.distortion_functions\
            import get_distortion_adult
from aif360.algorithms.preprocessing.optim_preproc_helpers.opt_tools import OptTools
"""
# Out:
# '\n# if you need "OptimPreproc"\nfrom aif360.algorithms.preprocessing.optim_preproc import OptimPreproc\nfrom aif360.algorithms.preprocessing.optim_preproc_helpers.distortion_functions            import get_distortion_adult\nfrom aif360.algorithms.preprocessing.optim_preproc_helpers.opt_tools import OptTools\n'

# %%
class Projpreprocess:
    
    def __init__(self,traindata,x_list,var_list,K,e):

        self.K=K
        self.e=e
        self.x_list=x_list
        self.var_list=var_list
      
        self.var_dim=len(var_list)
        self.arg_list=[elem for elem in var_list if elem not in x_list]
        self.train = traindata.copy()
        self.df = self.train.convert_to_dataframe()[0]
        self.pa = self.train.protected_attribute_names[0]
        self.pa_index = self.train.feature_names.index(pa)
        self.label_name = self.train.label_names[0]
        self.df=self.df.rename(columns={self.pa:'S',self.label_name:'Y'})

        self.df['W'] = self.train.instance_weights
        for col in self.var_list+['S','Y']:
            self.df[col]=self.df[col].astype('int64')
        self.df=self.df[var_list+['S','W','Y']]
        if len(x_list)>1:
            self.df['X'] = list(zip(*[self.df[c] for c in x_list]))
            self.x_range=sorted(set(self.df['X']))
            weight=list(1/(self.df[x_list].max()-self.df[x_list].min())) # because ranges of attributes differ
            self.C=c_generate_higher(self.x_range,weight)
        else:
            self.df['X']=self.df[x_list]
            self.x_range=sorted(set(self.df['X']))
            self.C=c_generate(self.x_range)
        self.df = self.df[self.arg_list+['X','S','Y','W']].groupby(by=self.arg_list+['X','S','Y'],as_index=False).sum()
        self.distribution_generator()
        
    def distribution_generator(self):
        bin=len(self.x_range)
        dist=rdata_analysis(self.df,self.x_range,'X')
        dist['v']=[(dist['x_0'][i]-dist['x_1'][i])/dist['x'][i] for i in range(bin)]
        dist['t_x']=dist['x'] # #dist['x'] #dist['x_0']*0.5+dist['x_1']*0.5 
        self.px=np.matrix(dist['x']).T
        self.ptx=np.matrix(dist['t_x']).T
        if np.any(dist['x_0']==0): 
            self.p0=np.matrix((dist['x_0']+1.0e-9)/sum(dist['x_0']+1.0e-9)).T
        else:
            self.p0=np.matrix(dist['x_0']).T 
        if np.any(dist['x_1']==0):
            self.p1=np.matrix((dist['x_1']+1.0e-9)/sum(dist['x_1']+1.0e-9)).T
        else:
            self.p1=np.matrix(dist['x_1']).T 
        self.V=np.matrix(dist['v']).T
        # self.tv_origin=sum(abs(dist['x_0']-dist['x_1']))/2
        # return px,ptx,V,p0,p1
    
    def coupling_generator(self,method,Theta=1e-2):
        print(Theta)
        if method == 'unconstrained':
            coupling=baseline(self.C,self.e,self.px,self.ptx,self.K)
        elif method == 'barycentre':
            coupling=baseline(self.C,self.e,self.p0,self.p1,self.K)
        elif method == 'partial':
            coupling=partial_repair(self.C,self.e,self.px,self.ptx,self.V,Theta,self.K)
        return coupling

    def preprocess(self,method,Theta=1e-2):
        coupling = self.coupling_generator(method,Theta)
        if len(self.x_list)>1:
            df_proj=projection_higher(self.df,coupling,self.x_range,self.x_list,self.var_list)
        else:
            df_proj=projection(self.df,coupling,self.x_range,self.x_list[0],self.var_list)
        df_proj = df_proj.groupby(by=self.arg_list+['X','S','Y'],as_index=False).sum()
        X=list(zip(*df_proj['X']))
        df_proj = df_proj.assign(**{self.x_list[i]:X[i] for i in range(len(self.x_list))})
        df_proj=df_proj.drop('X',axis=1)
        df_proj=df_proj.rename(columns={'S':self.pa,'Y':self.label_name})
        binaryLabelDataset = BinaryLabelDataset(
            favorable_label=0,
            unfavorable_label=1,
            df=df_proj.drop('W',axis=1), 
            label_names=self.train.label_names,
            protected_attribute_names=self.train.protected_attribute_names,
            privileged_protected_attributes=[np.array([1.0])],unprivileged_protected_attributes=[np.array([0.])])
        binaryLabelDataset.instance_weights = df_proj['W'].tolist()
        # return binaryLabelDataset.align_datasets(self.train)
        return self.train.align_datasets(binaryLabelDataset)

# %%
class Baselinepreprocess:

    def __init__(self,train,test):
        self.train = train
        self.test = test
        self.pa = train.protected_attribute_names[0]
        self.pa_index = train.feature_names.index(pa)
        self.prigroups = [{self.pa: 1}]
        self.unprigroups = [{self.pa: 0}]

    def preprocessing(self,method):
        test_tranf = self.test.copy()
        if method == 'RW':
            RW = Reweighing(privileged_groups = self.prigroups,unprivileged_groups = self.unprigroups) #DisparateImpactRemover(repair_level = 1)
            RW.fit(self.train)
            train_tranf = RW.transform(self.train)
        elif method == 'DIremover':
            di = DisparateImpactRemover(repair_level = 1,sensitive_attribute=pa)
            train_tranf = di.fit_transform(self.train)
            test_tranf = di.fit_transform(self.test)
        elif method == 'LFR':
            TR = LFR(privileged_groups = self.prigroups,unprivileged_groups = self.unprigroups,
                     Az = 1, Ax = 0.01, Ay = 1,verbose=0)
            TR = TR.fit(self.train)
            train_tranf = TR.transform(self.train)
            test_tranf = TR.transform(self.test)
        elif method == 'OP':
            optim_options = {
                "distortion_fun": get_distortion_adult,
                "epsilon": 0.05,
                "clist": [0.99, 1.99, 2.99],
                "dlist": [.1, 0.05, 0]
            }
            OP = OptimPreproc(OptTools, optim_options)
            OP = OP.fit(self.train)
            train_tranf = OP.transform(self.train, transform_Y=True)
        return train_tranf, test_tranf

    def prediction(self,method,para=None):
        test_tranf = self.test.copy()
        if method == 'origin':
            train_tranf = self.train
        elif method in ['RW','DIremover','LFR','OP']:
            train_tranf,test_tranf = self.preprocessing(method)
        else:
            K=200
            e=0.01
            var_list=self.train.feature_names.copy()
            var_list.remove(self.pa)
            projpre=Projpreprocess(self.train,para['x_list'],var_list,K,e)
            train_tranf=projpre.preprocess(method,para['Theta'])

        di=self.DisparateImpact(train_tranf)
        print('Disparate Impact of train',di)

        if method != 'LFR':
            X_train = np.delete(train_tranf.features, self.pa_index, axis=1)
            y_train = train_tranf.labels.ravel()
            weight_train = train_tranf.instance_weights
            model=RandomForestClassifier(max_depth=5).fit(X_train,y_train, sample_weight=weight_train)

            X_test = np.delete(test_tranf.features, self.pa_index, axis=1)
            y_pred = model.predict(X_test)
        else:
            y_pred = test_tranf.labels
        return y_pred,di
    
    def DisparateImpact(self,data):
        di = pd.DataFrame({'S':data.protected_attributes.ravel().tolist(),
            'Y':data.labels.ravel().tolist(),
            'W':list(data.instance_weights)},columns=['S','Y','W'])
        privileged = self.train.privileged_protected_attributes[0][0]
        unprivileged = self.train.unprivileged_protected_attributes[0][0]
        numerator=sum(di[(di['S']==unprivileged)&(di['Y']==data.favorable_label)]['W'])/sum(di[di['S']==unprivileged]['W'])
        denominator=sum(di[(di['S']==privileged)&(di['Y']==data.favorable_label)]['W'])/sum(di[di['S']==privileged]['W'])
        if numerator==denominator:
            return 1
        return numerator/denominator

    def assess(self,method,para=None):
        if para != None:
            y_pred,di_train = self.prediction(method,para)
        else:
            y_pred,di_train = self.prediction(method)
        y_test_pred = self.test.copy()
        y_test_pred.labels = y_pred

        di=self.DisparateImpact(y_test_pred)
        f1_macro = f1_score(self.test.labels, y_pred, average='macro',sample_weight=self.test.instance_weights)
        f1_micro = f1_score(self.test.labels, y_pred, average='micro',sample_weight=self.test.instance_weights)
        f1_weighted = f1_score(self.test.labels, y_pred, average='weighted',sample_weight=self.test.instance_weights)
        print('Disparate Impact of '+str(method),di)
        print('f1 macro of '+str(method),f1_macro)

        new_row=pd.Series({'DI of train':di_train,'DI':di,'f1 macro':f1_macro,'f1 micro':f1_micro,'f1 weighted':f1_weighted,'method':method})
        return new_row.to_frame().T

# %% [markdown]
# # Compas

# %%
pa = 'race'
label_map = {1.0: 'Did recid.', 0.0: 'No recid.'}
protected_attribute_maps = {1.0: 'Caucasian', 0.0: 'Not Caucasian'}
privileged_groups = [{pa: 1}]
unprivileged_groups = [{pa: 0}]
cd = CompasDataset(protected_attribute_names=[pa],privileged_classes=[['Caucasian'],[1]], 
                    metadata={'label_map': label_map,'protected_attribute_maps': protected_attribute_maps},
                    features_to_drop=['age', 'sex', 'c_charge_desc'])
train,test = cd.split([0.6], shuffle=True) #len(test.instance_names) = 2057
var_list = cd.feature_names.copy()
var_list.remove(pa)
var_dim=len(var_list)

K=200
e=0.01

# df_train = df.loc[train.instance_names,:].reset_index(drop=True)
# df_test = df.loc[test.instance_names,:].reset_index(drop=True)
df=cd.convert_to_dataframe()[0]
df=df.rename(columns={pa:'S',cd.label_names[0]:'Y'})
df['W'] = cd.instance_weights
for col in var_list+['S','Y']:
    df[col]=df[col].astype('int64')
df=df[var_list+['S','W','Y']]

tv_dist=dict()
for x_name in var_list:
    x_range_single=list(pd.pivot_table(df,index=x_name,values=['W'],observed=False)[('W')].index) 
    dist=rdata_analysis(df,x_range_single,x_name)
    tv_dist[x_name]=sum(abs(dist['x_0']-dist['x_1']))/2
    print(x_name, tv_dist[x_name])
x_list=[]
for key,val in tv_dist.items():
    if val>0.1:
        x_list+=[key]
# Out:
# juv_fel_count 0.03210337325453563
# juv_misd_count 0.04323143324022939
# juv_other_count 0.021763780679615215
# priors_count 0.12622233191661625
# age_cat=25 - 45 0.054431947619680315
# age_cat=Greater than 45 0.13519019921101838
# age_cat=Less than 25 0.08075825159133806
# c_charge_degree=F 0.07840757396162046
# c_charge_degree=M 0.07840757396162046

# %%
methods=['origin','RW','DIremover','LFR'] 
report=pd.DataFrame(columns=['DI of train','DI','f1 macro','f1 micro','f1 weighted','method'])
for ignore in range(10):
    # train val test 4:2:4
    train,test = cd.split([0.4], shuffle=True) 
    valid,test = test.split([0.3], shuffle=True)
    
    prepro = Baselinepreprocess(train,test)
    for method in methods:
        report = pd.concat([report,prepro.assess(method)], ignore_index=True)

report.to_csv(path+'/data/report_preprocess_compas_'+str(pa)+'.csv',index=None)
# Out:
# Disparate Impact of train 0.8501498501498501
# Disparate Impact of origin 0.8110150329771941
# f1 macro of origin 0.6657045817367123
# Disparate Impact of train 0.9999999999999876
# Disparate Impact of RW 0.8153444873104502
# f1 macro of RW 0.6636959905135996
# Disparate Impact of train 0.8501498501498501
# Disparate Impact of DIremover 0.8120644715144422
# f1 macro of DIremover 0.6718030130982258
# Disparate Impact of train 0.9064355209799303
# Disparate Impact of LFR 0.979321286747445
# f1 macro of LFR 0.667290148623641
# Disparate Impact of train 0.864060434091483
# Disparate Impact of origin 0.7545292803054959
# f1 macro of origin 0.6675348748607937
# Disparate Impact of train 0.9999999999999662
# Disparate Impact of RW 0.7518792875953331
# f1 macro of RW 0.6690647635408862
# Disparate Impact of train 0.864060434091483
# Disparate Impact of DIremover 0.8496323249658728
# f1 macro of DIremover 0.6561949170649128
# Disparate Impact of train 1.0087223013659272
# Disparate Impact of LFR 0.9740349832398498
# f1 macro of LFR 0.6576262420366663
# Disparate Impact of train 0.8266640267915134
# Disparate Impact of origin 0.7801786471425542
# f1 macro of origin 0.6603396210663721
# Disparate Impact of train 0.9999999999999665
# Disparate Impact of RW 0.780220754716981
# f1 macro of RW 0.6597546973811304
# Disparate Impact of train 0.8266640267915134
# Disparate Impact of DIremover 0.8754688808036577
# f1 macro of DIremover 0.6566437484084543
# Disparate Impact of train 0.9053813044607811
# Disparate Impact of LFR 0.9331750716190853
# f1 macro of LFR 0.6515268210183465
# Disparate Impact of train 0.8144839924381709
# Disparate Impact of origin 0.7777939084231003
# f1 macro of origin 0.679326691858468
# Disparate Impact of train 1.0000000000000029
# Disparate Impact of RW 0.7933535112947945
# f1 macro of RW 0.6689791258612452
# Disparate Impact of train 0.8144839924381709
# Disparate Impact of DIremover 0.8697540721814117
# f1 macro of DIremover 0.6671080527902695
# Disparate Impact of train 0.9938881341859157
# Disparate Impact of LFR 1.0134634744167723
# f1 macro of LFR 0.6667375449320292
# Disparate Impact of train 0.8115367357060199
# Disparate Impact of origin 0.7580898166419084
# f1 macro of origin 0.6660661876636425
# Disparate Impact of train 1.0000000000000382
# Disparate Impact of RW 0.7550819816159109
# f1 macro of RW 0.6652246886752748
# Disparate Impact of train 0.8115367357060199
# Disparate Impact of DIremover 0.7905763906869286
# f1 macro of DIremover 0.6672207828287404
# Disparate Impact of train 0.9313997136769963
# Disparate Impact of LFR 0.9224029345009095
# f1 macro of LFR 0.6517247343165828
# Disparate Impact of train 0.9189684266327952
# Disparate Impact of origin 0.779718768205482
# f1 macro of origin 0.6511652082454307
# Disparate Impact of train 0.9999999999999862
# Disparate Impact of RW 0.7754620899543868
# f1 macro of RW 0.6533672396318964
# Disparate Impact of train 0.9189684266327952
# Disparate Impact of DIremover 0.9510229142469997
# f1 macro of DIremover 0.6293783988698836
# Disparate Impact of train 0.9454310371685829
# Disparate Impact of LFR 0.8656555181056089
# f1 macro of LFR 0.654645550420734
# Disparate Impact of train 0.8356032453256028
# Disparate Impact of origin 0.7736233957151133
# f1 macro of origin 0.6763584984083244
# Disparate Impact of train 0.9999999999999787
# Disparate Impact of RW 0.8031084327744339
# f1 macro of RW 0.6668325654763658
# Disparate Impact of train 0.8356032453256028
# Disparate Impact of DIremover 0.747563496751329
# f1 macro of DIremover 0.6639988943294663
# Disparate Impact of train 0.9526831807269869
# Disparate Impact of LFR 0.9784841731714605
# f1 macro of LFR 0.6674646261702217
# Disparate Impact of train 0.8465926901134725
# Disparate Impact of origin 0.8007456867676291
# f1 macro of origin 0.663232586688899
# Disparate Impact of train 1.0000000000000524
# Disparate Impact of RW 0.8188104492452317
# f1 macro of RW 0.6571052735367333
# Disparate Impact of train 0.8465926901134725
# Disparate Impact of DIremover 0.9426453307527476
# f1 macro of DIremover 0.6466921866050551
# Disparate Impact of train 0.922499573548644
# Disparate Impact of LFR 0.9215361606665954
# f1 macro of LFR 0.6546746695426522
# Disparate Impact of train 0.887750789849677
# Disparate Impact of origin 0.7839242474778759
# f1 macro of origin 0.6580553335835049
# Disparate Impact of train 0.9999999999999875
# Disparate Impact of RW 0.7912179171100097
# f1 macro of RW 0.6558236738881691
# Disparate Impact of train 0.887750789849677
# Disparate Impact of DIremover 0.8799779566612214
# f1 macro of DIremover 0.6627461910070604
# Disparate Impact of train 0.9247788488456934
# Disparate Impact of LFR 0.8918290486327165
# f1 macro of LFR 0.6595869047401477
# Disparate Impact of train 0.8299357728059739
# Disparate Impact of origin 0.7693948280458544
# f1 macro of origin 0.6592127485200223
# Disparate Impact of train 0.9999999999999618
# Disparate Impact of RW 0.7689521493455405
# f1 macro of RW 0.6604916656687967
# Disparate Impact of train 0.8299357728059739
# Disparate Impact of DIremover 0.8717289573844139
# f1 macro of DIremover 0.6559000258613154
# Disparate Impact of train 1.016183654508946
# Disparate Impact of LFR 1.0508512464783457
# f1 macro of LFR 0.6517968187124517

# %% [markdown]
# # Adult

# %%
var_list=['hoursperweek','age','capitalgain','capitalloss' ,'education-num'] #
var_dim=len(var_list)
pa='sex' #'race' #'sex'
pa_dict={'Male':1,'Female':0,'White':1,'Black':0}
pd.set_option('future.no_silent_downcasting', True)

messydata=pd.read_csv(path+'/data/adult_csv.csv',usecols=var_list+[pa,'class'])
messydata=messydata.rename(columns={'class':'Y'}) #pa:'S',
messydata[pa]=messydata[pa].replace(pa_dict)
messydata['Y']=messydata['Y'].replace({'>50K':1,'<=50K':0})
messydata=messydata[(messydata[pa]==1)|(messydata[pa]==0)]
for col in var_list+[pa,'Y']:
    messydata[col]=messydata[col].astype('category')
cd=BinaryLabelDataset(
    favorable_label=1,
    unfavorable_label=0,
    df=messydata,label_names='Y',protected_attribute_names=[pa])
train,test = cd.split([0.4], shuffle=True) 
valid,test = test.split([0.3], shuffle=True)  
var_list = cd.feature_names.copy()
var_list.remove(pa)
var_dim=len(var_list)

K=200
e=0.01

# df_train = df.loc[train.instance_names,:].reset_index(drop=True)
# df_test = df.loc[test.instance_names,:].reset_index(drop=True)
df=cd.convert_to_dataframe()[0]
df=df.rename(columns={pa:'S',cd.label_names[0]:'Y'})
df['W'] = cd.instance_weights
for col in var_list+['S','Y']:
    df[col]=df[col].astype('int64')
df=df[var_list+['S','W','Y']]

tv_dist=dict()
for x_name in var_list:
    x_range_single=list(pd.pivot_table(df,index=x_name,values=['W'],observed=False)[('W')].index) 
    dist=rdata_analysis(df,x_range_single,x_name)
    tv_dist[x_name]=sum(abs(dist['x_0']-dist['x_1']))/2
    print(x_name, tv_dist[x_name])
x_list=[]
for key,val in tv_dist.items():
    if val>0.1:
        x_list+=[key]
# Out:
# age 0.1010227688866829
# education-num 0.07095473385227195
# capitalgain 0.036924675713792855
# capitalloss 0.020068855964263464
# hoursperweek 0.18188704156553212

# %%
# para={'x_list':x_list,'Theta':1e-2}
methods=['origin','RW','DIremover','LFR'] 
report=pd.DataFrame(columns=['DI of train','DI','f1 macro','f1 micro','f1 weighted','method'])
for ignore in range(10):
    # train val test 4:2:4
    train,test = cd.split([0.4], shuffle=True) 
    valid,test = test.split([0.3], shuffle=True)
    
    prepro = Baselinepreprocess(train,test)
    for method in methods:
        report = pd.concat([report,prepro.assess(method)], ignore_index=True)

report.to_csv(path+'/data/report_preprocess_adult_'+str(pa)+'.csv',index=None)
# Out:
# Disparate Impact of train 0.35995327013796735
# Disparate Impact of origin 0.44524157233322886
# f1 macro of origin 0.6852455702546062
# Disparate Impact of train 1.0000000000001694
# Disparate Impact of RW 0.44915068392210383
# f1 macro of RW 0.6792102622851561
# Disparate Impact of train 0.35995327013796735
# Disparate Impact of DIremover 0.4448869724182876
# f1 macro of DIremover 0.6846075536339105
# Disparate Impact of train 0.7189370305121241
# Disparate Impact of LFR 0.6582539932401634
# f1 macro of LFR 0.6577962860741433
# Disparate Impact of train 0.3463471833492703
# Disparate Impact of origin 0.43845936651078676
# f1 macro of origin 0.685281951273913
# Disparate Impact of train 1.0000000000002955
# Disparate Impact of RW 0.4510791710334553
# f1 macro of RW 0.6756917265995288
# Disparate Impact of train 0.3463471833492703
# Disparate Impact of DIremover 0.43973020177022726
# f1 macro of DIremover 0.6797619798964105
# Disparate Impact of train 0.9127227532276828
# Disparate Impact of LFR 0.8900636352526226
# f1 macro of LFR 0.6934206472908451
# Disparate Impact of train 0.3536270840060824
# Disparate Impact of origin 0.5124694076017614
# f1 macro of origin 0.696745249024876
# Disparate Impact of train 0.9999999999999578
# Disparate Impact of RW 0.537171224103317
# f1 macro of RW 0.6879012542370477
# Disparate Impact of train 0.3536270840060824
# Disparate Impact of DIremover 0.5824289222415959
# f1 macro of DIremover 0.7091978720888286
# Disparate Impact of train 0.7903893917290206
# Disparate Impact of LFR 0.8538319199743633
# f1 macro of LFR 0.6180455748938329
# Disparate Impact of train 0.36503244188829376
# Disparate Impact of origin 0.46260901580391284
# f1 macro of origin 0.6895617900409781
# Disparate Impact of train 1.0000000000000377
# Disparate Impact of RW 0.5007123836451721
# f1 macro of RW 0.684811792251653
# Disparate Impact of train 0.36503244188829376
# Disparate Impact of DIremover 0.4567370387012642
# f1 macro of DIremover 0.6879373493432119
# Disparate Impact of train 0.8742934369998429
# Disparate Impact of LFR 0.8375596936593385
# f1 macro of LFR 0.686886156557589
# Disparate Impact of train 0.35748090288742973
# Disparate Impact of origin 0.43416082984443943
# f1 macro of origin 0.6816480510310464
# Disparate Impact of train 0.9999999999998382
# Disparate Impact of RW 0.446469705898109
# f1 macro of RW 0.6472694808623038
# Disparate Impact of train 0.35748090288742973
# Disparate Impact of DIremover 0.5004491694481354
# f1 macro of DIremover 0.6873155006751641
# Disparate Impact of train 0.863025697602265
# Disparate Impact of LFR 0.9008911692235994
# f1 macro of LFR 0.6879872924950269
# Disparate Impact of train 0.35404393128696143
# Disparate Impact of origin 0.42882024219196774
# f1 macro of origin 0.6789781118507964
# Disparate Impact of train 1.0000000000003169
# Disparate Impact of RW 0.5099102289067953
# f1 macro of RW 0.6922420070061494
# Disparate Impact of train 0.35404393128696143
# Disparate Impact of DIremover 0.42263082984060585
# f1 macro of DIremover 0.6853991883414333
# Disparate Impact of train 0.7302203900428097
# Disparate Impact of LFR 0.7410287372041625
# f1 macro of LFR 0.6919409791020823
# Disparate Impact of train 0.3681495873091822
# Disparate Impact of origin 0.47590115471932315
# f1 macro of origin 0.6848213606931377
# Disparate Impact of train 1.000000000000064
# Disparate Impact of RW 0.5792057851715036
# f1 macro of RW 0.6588495933905101
# Disparate Impact of train 0.3681495873091822
# Disparate Impact of DIremover 0.5342890274832065
# f1 macro of DIremover 0.6869654141967558
# Disparate Impact of train 0.8354965061736576
# Disparate Impact of LFR 0.8820109500317882
# f1 macro of LFR 0.6772208551167165
# Disparate Impact of train 0.3690255914673037
# Disparate Impact of origin 0.4109866519926594
# f1 macro of origin 0.6879972039985641
# Disparate Impact of train 0.9999999999999092
# Disparate Impact of RW 0.3987068456945984
# f1 macro of RW 0.6779994028194262
# Disparate Impact of train 0.3690255914673037
# Disparate Impact of DIremover 0.406697293343087
# f1 macro of DIremover 0.6848410287462101
# Disparate Impact of train 0.8505031802362462
# Disparate Impact of LFR 0.8415353728058161
# f1 macro of LFR 0.6882365968703249
# Disparate Impact of train 0.3496730439676595
# Disparate Impact of origin 0.45452545274185546
# f1 macro of origin 0.681852731546805
# Disparate Impact of train 1.000000000000092
# Disparate Impact of RW 0.4412846181003522
# f1 macro of RW 0.6718628520766483
# Disparate Impact of train 0.3496730439676595
# Disparate Impact of DIremover 0.438138750436042
# f1 macro of DIremover 0.673031093667467
# Disparate Impact of train 0.8199379510804818
# Disparate Impact of LFR 0.8341684926718462
# f1 macro of LFR 0.6877440354869476
# Disparate Impact of train 0.35741611681841656
# Disparate Impact of origin 0.4398965477584476
# f1 macro of origin 0.6737247302723628
# Disparate Impact of train 1.0000000000001754
# Disparate Impact of RW 0.4539472974411499
# f1 macro of RW 0.6700679863666894
# Disparate Impact of train 0.35741611681841656
# Disparate Impact of DIremover 0.4444005498845758
# f1 macro of DIremover 0.6755387318643887
# Disparate Impact of train 0.8130082800126283
# Disparate Impact of LFR 0.8292361313458244
# f1 macro of LFR 0.6807790679529867

# %%
report
# Out:
#    DI of train DI of test  f1 macro  f1 micro f1 weighted     method
# 0      0.47143   0.556036  0.708576  0.818451    0.801336     origin
# 1          1.0   0.568674  0.708122  0.818612    0.801214         RW
# 2      0.47143   0.556036  0.708576  0.818451    0.801336  DIremover
# 3     0.949888   1.026318  0.669162  0.808493    0.780458        LFR
# 4     0.452246   0.611655  0.714217  0.822703    0.806345     origin
# 5          1.0   0.583901  0.712151   0.82125    0.804873         RW
# 6     0.452246   0.611655  0.714217  0.822703    0.806345  DIremover
# 7            1          1  0.432338  0.761613    0.658549        LFR
# 8     0.500505   0.467203  0.712432  0.820227    0.804098     origin
# 9          1.0   0.474131   0.71036  0.821196    0.803644         RW
# 10    0.500505   0.467203  0.712432  0.820227    0.804098  DIremover
# 11     0.84925   0.773576  0.668626   0.79676    0.775909        LFR
# 12    0.445439   0.463386  0.704866   0.81802    0.798732     origin
# 13         1.0   0.467775  0.706419  0.818236    0.799482         RW
# 14    0.445439   0.463386  0.704866   0.81802    0.798732  DIremover
# 15           1          1   0.43079  0.756822    0.652064        LFR
# 16    0.494102   0.477678  0.710268  0.820927    0.803184     origin
# 17         1.0   0.474569  0.709999  0.821573    0.803342         RW
# 18    0.494102   0.477678  0.710268  0.820927    0.803184  DIremover
# 19    7.923916   5.743996  0.458975   0.76172    0.668988        LFR
# 20    0.453192   0.556436  0.708626   0.81802    0.801348     origin
# 21         1.0   0.546391  0.705892  0.817052    0.799797         RW
# 22    0.453192   0.556436  0.708626   0.81802    0.801348  DIremover
# 23     0.64409   0.759461  0.464407  0.766403    0.673278        LFR
# 24    0.478881    0.50447  0.711181  0.821088    0.803635     origin
# 25         1.0   0.504864  0.710378  0.822057    0.803704         RW
# 26    0.478881    0.50447  0.711181  0.821088    0.803635  DIremover
# 27           1          1  0.431644   0.75946    0.655632        LFR
# 28    0.457843   0.493177  0.714825  0.819312    0.803062     origin
# 29         1.0   0.494944  0.715288   0.81942    0.803303         RW
# 30    0.457843   0.493177  0.714825  0.819312    0.803062  DIremover
# 31           1          1  0.430389  0.755584     0.65039        LFR
# 32    0.487866   0.529176  0.706358  0.820335    0.802827     origin
# 33         1.0   0.533858  0.705878  0.820119    0.802538         RW
# 34    0.487866   0.529176  0.706358  0.820335    0.802827  DIremover
# 35    0.939329   1.012011  0.708425  0.805479    0.797131        LFR
# 36    0.488844   0.507426  0.709523  0.821357    0.804196     origin
# 37         1.0   0.512846   0.70892  0.821142    0.803856         RW
# 38    0.488844   0.507426  0.709523  0.821357    0.804196  DIremover
# 39    0.830194   0.843962  0.705098  0.813015    0.798804        LFR

# %%
pa = 'sex'
label_map = {1.0: 'Did recid.', 0.0: 'No recid.'}
protected_attribute_maps = [{1.0: 'Female', 0.0: 'Male'}]
privileged_groups = [{pa: 1}]
unprivileged_groups = [{pa: 0}]
cd = CompasDataset(protected_attribute_names=[pa],privileged_classes=[['Female'],[1]], 
                    metadata={'label_map': label_map,'protected_attribute_maps': protected_attribute_maps},
                    features_to_drop=['age', 'race', 'c_charge_desc'])
train,test = cd.split([0.6], shuffle=True) #len(test.instance_names) = 2057
var_list = cd.feature_names.copy()
var_list.remove(pa)
var_dim=len(var_list)

K=200
e=0.01

# df_train = df.loc[train.instance_names,:].reset_index(drop=True)
# df_test = df.loc[test.instance_names,:].reset_index(drop=True)
df=cd.convert_to_dataframe()[0]
df=df.rename(columns={pa:'S',cd.label_names[0]:'Y'})
df['W'] = cd.instance_weights
for col in var_list+['S','Y']:
    df[col]=df[col].astype('int64')
df=df[var_list+['S','W','Y']]

tv_dist=dict()
for x_name in var_list:
    x_range_single=list(pd.pivot_table(df,index=x_name,values=['W'],observed=False)[('W')].index) 
    dist=rdata_analysis(df,x_range_single,x_name)
    tv_dist[x_name]=sum(abs(dist['x_0']-dist['x_1']))/2
    print(x_name, tv_dist[x_name])
x_list=[]
for key,val in tv_dist.items():
    if val>0.07:
        x_list+=[key]
# Out:
# juv_fel_count 0.03216431986851686
# juv_misd_count 0.034702012696979916
# juv_other_count 0.04940751685053583
# priors_count 0.1440012943936575
# age_cat=25 - 45 0.01744161390451293
# age_cat=Greater than 45 0.006471116712580785
# age_cat=Less than 25 0.010970497191932188
# c_charge_degree=F 0.07546689715957233
# c_charge_degree=M 0.07546689715957233

# %%
report
# Out:
#    DI of train DI of test  f1 macro  f1 micro f1 weighted     method
# 0     0.839708   0.782995  0.642804  0.652086    0.648891     origin
# 1          1.0   0.790689  0.642784  0.652491    0.649009         RW
# 2     0.839708   0.874399  0.649171  0.661401    0.656095  DIremover
# 3     0.942215   0.992864  0.451882  0.499797    0.469013        LFR
# 4     0.839708   0.810368  0.627069  0.647226    0.636234    partial
# 5     0.809257   0.769357  0.640496  0.644795    0.643251     origin
# 6          1.0   0.771609  0.641316  0.645606    0.644064         RW
# 7     0.809257   0.895601  0.644817  0.654516     0.64893  DIremover
# 8     1.112686   1.181917  0.399111   0.44755    0.387157        LFR
# 9     0.809257    0.81182   0.62397   0.63872    0.629188    partial
# 10    0.849524   0.790531  0.658296  0.670312    0.663564     origin
# 11         1.0   0.791358  0.658811  0.671122    0.664139         RW
# 12    0.849524   0.764407  0.661803  0.667882    0.665531  DIremover
# 13         1.0        1.0  0.351117   0.54111    0.379986        LFR
# 14    0.849524   0.815104  0.634028  0.651276     0.64056    partial
# 15    0.838718   0.776429  0.671357  0.681652     0.67727     origin
# 16         1.0   0.767653  0.666829  0.673147    0.671493         RW
# 17    0.838718   0.878947  0.656523  0.667882    0.662873  DIremover
# 18    1.045113   0.815299  0.492095  0.492102    0.491907        LFR
# 19    0.838718   0.824651  0.653353  0.671122    0.661331    partial
# 20    0.829061   0.780732  0.648694  0.656541    0.654712     origin
# 21         1.0   0.785213  0.649523  0.657351    0.655527         RW
# 22    0.829061   0.843251  0.649363  0.658566    0.655874  DIremover
# 23    1.006083   0.975221   0.44921  0.566221    0.478308        LFR
# 24    0.829061   0.803113  0.635045  0.645606    0.642161    partial
# 25     0.84206   0.758486  0.657956  0.666667    0.662886     origin
# 26         1.0   0.778876  0.648441  0.660591    0.654344         RW
# 27     0.84206   0.828439  0.649989  0.663832    0.656276  DIremover
# 28    0.945961   0.972581  0.393428  0.553665    0.421587        LFR
# 29     0.84206   0.788578   0.63521  0.654516    0.642789    partial
# 30    0.829173   0.811896  0.647699  0.656946    0.651375     origin
# 31         1.0   0.816319   0.64706  0.655731    0.650622         RW
# 32    0.829173   0.913377  0.639397  0.648441    0.643075  DIremover
# 33    1.042728   0.728702  0.488393  0.508708    0.481827        LFR
# 34    0.829173   0.886275  0.606684   0.63386    0.613342    partial
# 35    0.843994   0.752806  0.661484  0.668287    0.665663     origin
# 36         1.0    0.75242  0.660578  0.667477    0.664792         RW
# 37    0.843994   0.775915  0.651148  0.656541    0.654925  DIremover
# 38    0.918983     0.7165   0.49067  0.535439    0.477521        LFR
# 39    0.843994   0.787558  0.638182  0.652491    0.644448    partial
# 40    0.836232   0.761991  0.642132  0.649656    0.646818     origin
# 41         1.0   0.782913   0.63165   0.64277     0.63743         RW
# 42    0.836232   0.771561  0.635854  0.639125    0.638971  DIremover
# 43    0.418882   0.988679  0.438414  0.466181    0.449693        LFR
# 44    0.836232   0.812766  0.612069   0.63224    0.620058    partial
# 45     0.84322   0.797652  0.664936  0.675577    0.670136     origin
# 46         1.0   0.798603  0.662283  0.672337    0.667357         RW
# 47     0.84322    0.77433  0.657938  0.663021    0.661569  DIremover

# %%
report.to_csv(path+'/data/report_preprocess_compas_'+str(pa)+'_'+str(para['Theta'])+'.csv',index=None)

# %%
Baselinepreprocess(train,test).assess('partial',para=para)
# Out:
# 0.01
# Disparate Impact of train 0.8636921817437819
# Disparate Impact of partial 0.8029550791375681
# f1 macro of partial 0.6464155528554071

# %%
Baselinepreprocess(train,test).assess('LFR')
# Out:
# Disparate Impact of train 1.0
# Disparate Impact of LFR 1.0
# f1 macro of LFR 0.543134872417983

# %%
Baselinepreprocess(train,test).assess('RW')
# Out:
# Disparate Impact of train 1.000000000000009
# Disparate Impact of RW 0.7882558927630092
# f1 macro of RW 0.6618063993519644

# %%
Baselinepreprocess(train,test).assess('DIremover')
# Out:
# Disparate Impact of train 0.8636921817437576
# Disparate Impact of DIremover 0.859092543994032
# f1 macro of DIremover 0.6634264884568651

# %%
Baselinepreprocess(train,test).assess('origin')
# Out:
# Disparate Impact of train 0.8636921817437576
# Disparate Impact of origin 0.7855305825785532
# f1 macro of origin 0.6626164439044148
